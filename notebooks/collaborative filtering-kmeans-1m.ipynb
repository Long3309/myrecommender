# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("../enrich/movies.csv")
ratings = pd.read_csv("../enrich/ratings.csv")

# %%
movies
# Out:
#       movieid                               title  \
# 0           0                    Toy Story (1995)
# 1           1                      Jumanji (1995)
# 2           2             Grumpier Old Men (1995)
# 3           3            Waiting to Exhale (1995)
# 4           4  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3878             Meet the Parents (2000)
# 3879     3879          Requiem for a Dream (2000)
# 3880     3880                    Tigerland (2000)
# 3881     3881             Two Family House (2000)
# 3882     3882               Contender, The (2000)
#
#                             genres
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# 3880                         Drama
# ...

# %%
# ratings.sort_values(by = "userid").to_csv("../enrich/ratings.csv", index=False)
ratings
# Out:
#          userid  movieid  rating  timestamp  \
# 0             1     1176       5  978300760
# 1             1       47       5  978824351
# 2             1      926       4  978301752
# 3             1     1189       4  978300719
# 4             1     1672       4  978300055
# ...         ...      ...     ...        ...
# 1000204    6040     2572       2  956716343
# 1000205    6040     1878       4  997454036
# 1000206    6040      892       4  956716845
# 1000207    6040     2595       4  957717463
# 1000208    6040     1157       2  956716317
#
#                                                    title  \
# 0                 One Flew Over the Cuckoo's Nest (1975)
# 1                                      Pocahontas (1995)
# 2                                            Gigi (1958)
# 3                           To Kill a Mockingbird (1962)
# 4                                         Titanic (1997)
# ...                                                  ...
# ...

# %%
for x in ratings.groupby("userid").groups:
    print(ratings.groupby("userid").get_group(1))
    break
# Out:
#     userid  movieid  rating  timestamp  \
# 0        1     1176       5  978300760
# 1        1       47       5  978824351
# 2        1      926       4  978301752
# 3        1     1189       4  978300719
# 4        1     1672       4  978300055
# 5        1     2693       4  978302091
# 6        1     2618       3  978824268
# 7        1     2623       4  978301570
# 8        1      711       3  978300760
# 9        1      735       3  978824268
# 10       1      591       5  978824268
# 11       1     1892       5  978301590
# 12       1      523       5  978824195
# 13       1     1081       4  978301953
# 14       1     2735       5  978300719
# 15       1     1949       4  978301777
# 16       1      604       4  978301398
# 17       1     1893       4  978301753
# 18       1     1267       5  978302039
# 19       1      584       4  978824268
# 20       1     1226       4  978302091
# 21       1      902       3  978301968
# 22       1     1179       3  978302268
# ...
